# %% [markdown]
# ### Exercises

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Jay\Documents\Instacart Basket Analysis'

# %%
# import merged data
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data Sets', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
# create subset
df = df_ords_prods_merge[:1000000]

# %%
# create price_label column

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# apply the above function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\Jay\AppData\Local\Temp/ipykernel_10828/1709779114.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# ...

# %%
df.shape
# Out:
# (1000000, 17)

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    672525
# Low-range product    314109
# High range            12413
# Not enough data         953
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# ##### Max price value detected needs investigation.

# %%
# conditions w/loc()
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\Jay\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\Jay\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     672525
# Low-range product     314109
# High-range product     12413
# NaN                      953
# Name: price_range_loc, dtype: int64

# %%
# repeat process on entire dataframe
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# NaN                   21218535
# Low-range product     10126321
# Mid-range product       672525
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
df_ords_prods_merge.shape
# Out:
# (32435059, 17)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# ...

# %%
# create busiest day column w/for-loop

result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
df_ords_prods_merge['Busiest day'] = result

# %%
df_ords_prods_merge['Busiest day'].value_counts(dropna = False)
# Out:
# Regularly busy    22437988
# Busiest day        6209808
# Least busy         3787263
# Name: Busiest day, dtype: int64

# %%
df_ords_prods_merge.shape
# Out:
# (32435059, 18)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# ...

# %% [markdown]
# ### Task 4.7

# %%
# additional data for “Busiest days”
add_result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    add_result.append("Busiest_days")
  elif value == 1:
    add_result.append("Busiest_days")
  elif value == 3:
    add_result.append("Slowest_days")
  elif value ==4:
    add_result.append("Slowest_days")
  else:
    add_result.append("Regularly busy")

# %%
add_result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
# ...

# %%
df_ords_prods_merge['Busiest_days'] = add_result

# %%
df_ords_prods_merge['Busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12927862
# Busiest_days      11875759
# Slowest_days       7631438
# Name: Busiest_days, dtype: int64

# %% [markdown]
# ##### As expected, a noteable increase in Busiest & Slowest days, with resulting decrease in Regularly busy.

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (32435059, 19)

# %%
# identify busiest hours of the day
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2764476
# 11    2738647
# 14    2691598
# 15    2664583
# 13    2663346
# 12    2620898
# 16    2537506
# 9     2456751
# 17    2089510
# 8     1719991
# 18    1637956
# 19    1259416
# 20     977049
# 7      891951
# 21     796379
# 22     634743
# 23     402621
# 6      290796
# 0      218951
# 1      115787
# 5       88064
# 2       69435
# 4       53284
# 3       51321
# Name: order_hour_of_day, dtype: int64

# %%
hours_result = []

for value in df_ords_prods_merge["order_hour_of_day"]:
  if value >=9 & value <=17:
    hours_result.append("Most_orders")
  elif value <=6:
    hours_result.append("Fewest_orders")
  else:
    hours_result.append("Average_orders")

# %%
hours_result
# Out:
# ['Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
# ...

# %%
# create busiest_period_of_day column
df_ords_prods_merge['busiest_period_of_day'] = hours_result

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders    32435059
# Name: busiest_period_of_day, dtype: int64

# %%
df_ords_prods_merge.shape
# Out:
# (32435059, 20)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  new_customer  product_id  \
# 0                  8                     NaN          True         196
# 1                  8                     NaN          True       14084
# 2                  8                     NaN          True       12427
# 3                  8                     NaN          True       26088
# 4                  8                     NaN          True       26405
#
#    add_to_cart_order  reordered                             product_name  \
# 0                  1          0                                     Soda
# ...

# %%
# export to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data Sets','Prepared Data', 'ords_prods_merge_new.pkl'))
